# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as sco

# %%
plt.figure(1,figsize=(12,6))
plt.rcParams["axes.facecolor"] = "#94c9f9"
#plt.title(r"Diagrama de fase $\Omega-T$ para la solución ferromagnética",fontsize=25)
plt.title(r"Phase diagram",fontsize=25)
plt.xlabel(r"$\eta/\gamma_m$",fontsize=25)
plt.ylabel(r"$\Delta/\gamma_m$",fontsize=25)

plt.ylim(0,30)

x=np.linspace(0.0000,0.4,1000)

def f(x):
    return 2*x



x = np.linspace(0, 1, 10000)

x=10000*(499**x-1)/498
#Primera fase
plt.plot(x,2*x,color="#000000")
#plt.fill_between(x, np.sqrt((1/x-1)/8), where=x <= 1 , facecolor="green",alpha=0.5)


plt.fill_between(x,f(x), where=x <= 1000000, facecolor="#ffdbdb",alpha=0.5)

plt.text(10**(-1),15,"Oscillations",fontsize=20)
plt.text(10**(2),15,"Stable point",fontsize=20)
#plt.text(0.2,0.8,"Ciclo límite",fontsize=20)

plt.xlim(10**(np.log10(x[1])),10**(np.log10(x[-1])))

plt.xscale("log")

plt.savefig("Diagrama_de_fase_solucion_ferromagnetica.png",format="png",bbox_inches="tight")
